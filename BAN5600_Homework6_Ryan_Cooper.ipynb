# %%
# Homework 6 - RapidAPI Weather Demo
# Name: Ryan Cooper
# Course: BAN 5600
# Professor: Omar El Mghari
# 5/03/2026
# AI Use Statement:
# I used AI as a study support tool to help me understand RapidAPI,
# organize my notebook, and prepare my explanation. I reviewed the
# final notebook myself and I am responsible for the final submission.

# %%
import requests
from pprint import pprint

# %%
url = "https://open-weather13.p.rapidapi.com/city"

querystring = {"city":"new york","lang":"EN"}

headers = {
	"x-rapidapi-key": "0174c902f4msh8c6bf1c14cc3403p15f294jsn0695fa3cc0a8",
	"x-rapidapi-host": "open-weather13.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
print("Status code:", response.status_code)
pprint(response.json())
# Out:
# Status code: 200
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.7143, 'lon': -74.006},
#  'dt': 1777818115,
#  'id': 5128581,
#  'main': {'feels_like': 48.42,
#           'grnd_level': 1011,
#           'humidity': 43,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 51.55,
#           'temp_max': 54.01,
#           'temp_min': 49.95},
#  'name': 'New York',
#  'sys': {'country': 'US',
#          'id': 4610,
#          'sunrise': 1777801925,
#          'sunset': 1777852415,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 298, 'gust': 24, 'speed': 18.01}}

# %%
weather_data = response.json()

print("City:", weather_data["name"])
print("Country:", weather_data["sys"]["country"])
print("Temperature:", weather_data["main"]["temp"])
print("Feels Like:", weather_data["main"]["feels_like"])
print("Humidity:", weather_data["main"]["humidity"])
print("Weather Description:", weather_data["weather"][0]["description"])
print("Wind Speed:", weather_data["wind"]["speed"])
# Out:
# City: New York
# Country: US
# Temperature: 51.55
# Feels Like: 48.42
# Humidity: 43
# Weather Description: clear sky
# Wind Speed: 18.01
